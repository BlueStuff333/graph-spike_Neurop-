# %%
# Program assesses the generated spikes

# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
data = loadmat("graph-spike_.mat")
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'adj', 'e_locs', 'firings', 'i_locs'])

# %%
firings = data['firings']
print(type(firings))
print(firings.shape)

plt.plot(firings[:, 0], firings[:, 1], 'k|', markersize=2)
plt.xlabel('Time')
plt.ylabel('Neuron Index')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# (22388, 2)
